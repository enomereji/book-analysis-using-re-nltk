# %%
pip install nltk
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting nltk
# ...
#      ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#       --------------------------------------- 0.0/1.5 MB ? eta -:--:--
#       --------------------------------------- 0.0/1.5 MB ? eta -:--:--
#       --------------------------------------- 0.0/1.5 MB ? eta -:--:--
#      -- ------------------------------------- 0.1/1.5 MB 416.7 kB/s eta 0:00:04
#      -- ------------------------------------- 0.1/1.5 MB 467.6 kB/s eta 0:00:03
#      -- ------------------------------------- 0.1/1.5 MB 467.6 kB/s eta 0:00:03
#      ---- ----------------------------------- 0.2/1.5 MB 416.7 kB/s eta 0:00:04
#      ----- ---------------------------------- 0.2/1.5 MB 471.4 kB/s eta 0:00:03
#      ------ --------------------------------- 0.2/1.5 MB 558.1 kB/s eta 0:00:03
#      ------- -------------------------------- 0.3/1.5 MB 553.0 kB/s eta 0:00:03
# ...
